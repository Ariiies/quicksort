# %% [markdown]
# **Import Quicksort hirose version and defines an unsorted list.**

# %%
from quicksort_hirose import quicksort 

data = [4,5,9,10,16,1,8,7,2,6,14]

# %% [markdown]
# **Show the data. This function don't uses sublists for the sort, what is means that modifies the original list. So, more input data is needed for the pointiers.**

# %%
print("Unsorted list")
print(data)
size = len(data)
quicksort(data, 0, size - 1)
print('--- List in ascending sorting ---')
print(data)
quicksort(data, 0, size - 1,True)
print('--- List in descending sorting ---')
print(data)
print("--- Original list ---")
print(data)
# Out:
# Unsorted list
# [4, 5, 9, 10, 16, 1, 8, 7, 2, 6, 14]
# --- List in ascending sorting ---
# [1, 2, 4, 5, 6, 7, 8, 9, 10, 14, 16]
# --- List in descending sorting ---
# [16, 14, 10, 9, 8, 7, 6, 5, 4, 2, 1]
# --- Original list ---
# [16, 14, 10, 9, 8, 7, 6, 5, 4, 2, 1]
